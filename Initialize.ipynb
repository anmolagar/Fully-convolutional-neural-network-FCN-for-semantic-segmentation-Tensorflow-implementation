# %%
# !git clone https://github.com/anmolagar/Fully-convolutional-neural-network-FCN-for-semantic-segmentation-Tensorflow-implementation.git
# Out:
# Cloning into 'Fully-convolutional-neural-network-FCN-for-semantic-segmentation-Tensorflow-implementation'...
# remote: Counting objects: 81, done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (81/81), done.

# %%
cd Fully-convolutional-neural-network-FCN-for-semantic-segmentation-Tensorflow-implementation/
# Out:
# /content/Fully-convolutional-neural-network-FCN-for-semantic-segmentation-Tensorflow-implementation

# %%
ls
# Out:
# BuildNetVgg16.py     Figure1.png              README.md
# CheckVGG16Model.py   Inference.py             TensorflowUtils.py
# Data_Reader.py       IOU.py                   TRAIN.py
# Evaluate_Net_IOU.py  OverrlayLabelOnImage.py

# %%
# !./wgetgdrive.sh 0B6njwynsu2hXRFpmY1pOV1A4SFE Materials_In_Vessels.zip
# Out:
# --2018-07-06 10:08:56--  https://docs.google.com/uc?export=download&confirm=uNOt&id=0B6njwynsu2hXRFpmY1pOV1A4SFE
# Resolving docs.google.com (docs.google.com)... 74.125.142.101, 74.125.142.102, 74.125.142.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/p0e5emnqlg3713u3uhk64k1kqa5ldpn7/1530871200000/12873324072378008195/*/0B6njwynsu2hXRFpmY1pOV1A4SFE?e=download [following]
# ...
# --2018-07-06 10:08:56--  https://doc-14-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/p0e5emnqlg3713u3uhk64k1kqa5ldpn7/1530871200000/12873324072378008195/*/0B6njwynsu2hXRFpmY1pOV1A4SFE?e=download
# Resolving doc-14-38-docs.googleusercontent.com (doc-14-38-docs.googleusercontent.com)... 74.125.197.132, 2607:f8b0:400e:c08::84
# ...

# %%
# !unzip Materials_In_Vessels.zip -d Data_Zoo/
# Out:
# Archive:  Materials_In_Vessels.zip
#    creating: Data_Zoo/Materials_In_Vessels/
#    creating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/3 Summer Sangria Recipes-screenshot (2).png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/6 Classic Cocktail Recipes!-screenshot (1).png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/6 Classic Cocktail Recipes!-screenshot (2).png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/6 Classic Cocktail Recipes!-screenshot.png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/A Gas Phase Reaction- Producing Ammonium Chloride-screenshot (2).png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/A Gas Phase Reaction- Producing Ammonium Chloride-screenshot (3).png
#   inflating: Data_Zoo/Materials_In_Vessels/ExactPhaseLabels/A Gas Phase Reaction- Producing Ammonium Chloride-screenshot.png
# ...

# %%
# !./wgetgdrive.sh 0B6njwynsu2hXZWcwX0FKTGJKRWs vgg16.npy
# Out:
# --2018-07-06 10:14:36--  https://docs.google.com/uc?export=download&confirm=w8nn&id=0B6njwynsu2hXZWcwX0FKTGJKRWs
# Resolving docs.google.com (docs.google.com)... 74.125.142.138, 74.125.142.101, 74.125.142.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9qp0qveqvp50q4eidhusui9bjjeakr60/1530871200000/12873324072378008195/*/0B6njwynsu2hXZWcwX0FKTGJKRWs?e=download [following]
# ...
# --2018-07-06 10:14:36--  https://doc-0o-38-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9qp0qveqvp50q4eidhusui9bjjeakr60/1530871200000/12873324072378008195/*/0B6njwynsu2hXZWcwX0FKTGJKRWs?e=download
# Resolving doc-0o-38-docs.googleusercontent.com (doc-0o-38-docs.googleusercontent.com)... 74.125.142.132, 2607:f8b0:400e:c08::84
# ...

# %%
# !mkdir Model_Zoo
# !mv vgg16.npy Model_Zoo/

# %%
# !ls
# Out:
# BuildNetVgg16.py     Figure1.png	       OverrlayLabelOnImage.py
# CheckVGG16Model.py   Inference.py	       README.md
# Data_Reader.py	     IOU.py		       TensorflowUtils.py
# Data_Zoo	     Materials_In_Vessels.zip  TRAIN.py
# Evaluate_Net_IOU.py  Model_Zoo		       wgetgdrive.sh

# %%
# !python TRAIN.py
# Out:
# npy file loaded
# build model started
# WARNING:tensorflow:From /content/Fully-convolutional-neural-network-FCN-for-semantic-segmentation-Tensorflow-implementation/BuildNetVgg16.py:110: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# FCN model built
# WARNING:tensorflow:From TRAIN.py:56: calling squeeze (from tensorflow.python.ops.array_ops) with squeeze_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# Setting up Saver...
# 2018-07-06 10:31:02.474185: W tensorflow/core/framework/allocator.cc:108] Allocation of 411041792 exceeds 10% of system memory.
# 2018-07-06 10:31:02.851866: W tensorflow/core/framework/allocator.cc:108] Allocation of 411041792 exceeds 10% of system memory.
# ...
